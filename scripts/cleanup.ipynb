# %%
import os
import sys
import locale
import re
from dotenv import load_dotenv, find_dotenv
import psycopg2

load_dotenv(find_dotenv(filename='MF.env'))
locale.setlocale(locale.LC_COLLATE, "lt_LT.UTF-8")
z_dir = os.getenv("z_dir")
opus_dir = os.getenv("opus_dir")

conn = psycopg2.connect(
    dbname=os.getenv("database"),
    user=os.getenv("user"),
    password=os.getenv("password"),
    host=os.getenv("host"),
    port=os.getenv("port")
) 

cur = conn.cursor()

# %%
def read_chunks(file_name):
    file_name = f"{file_name}.md"
    chunks_path = os.path.join(z_dir, file_name)
    chunks = []
    with open(chunks_path, "r", encoding="utf-8") as file:
        chunks += [line.strip().split(", ") for line in file if line.strip()]
        return chunks

def append_words(file_name, words):
    file_path = os.path.join(z_dir, f"{file_name}.md")
    with open(file_path
    , "a", encoding="utf-8") as file:
        stringed_words = "\n\n".join(words)
        if stringed_words: stringed_words = "\n\n" + stringed_words
        file.write(stringed_words)
    return

def empty_file(file_name):
    file_name_ = f"{file_name}.md"
    backup_name = f"{file_name}_backup.md"
    chunks_path = os.path.join(z_dir, file_name_)
    backup_path = os.path.join(z_dir, backup_name)
    with open(chunks_path, "r", encoding="utf-8") as file:
        with open(backup_path, "w", encoding="utf-8") as backup:
            backup.write(file.read())
    with open(chunks_path, "w", encoding="utf-8") as file:
        file.write("[[()_Rėpas]]")
        return None

# %%
cores = read_chunks("cores")
cores = [item for item in cores if "delete" not in item]

# %%
to_core_pairs = tuple((item[0], core) for item in cores for core in item[1:])

# %%
new_morphs = tuple((item[1],) for item in to_core_pairs)

# %%
insert_morph_to_morphs_query = f"""
INSERT INTO morphs (morph, entered)
VALUES (%s, 1)
ON CONFLICT (morph) DO UPDATE SET entered = morphs.entered + 1
RETURNING id;
"""

# %%
cur.executemany(insert_morph_to_morphs_query, new_morphs)

# %%
conn.commit()

# %%
to_core_pairs
# Out:
# (('abejingo', 'abejoti'),
#  ('abstraktus', 'abstraktus'),
#  ('abudu', 'du'),
#  ('acetilakrilatas', 'acetilakrilatas'),
#  ('adamkus', 'valdasadamkus'),
#  ('adata', 'adata'),
#  ('adrenalinas', 'adrenalinas'),
#  ('afganistano', 'afganistanas'),
#  ('afrodiziakas', 'afrodiziakas'),
#  ('agnostikas', 'agnostika'),
#  ('agregacija', 'agreguoti'),
#  ('aguona', 'aguona'),
#  ('aguonėlė', 'aguona'),
#  ('aguonos', 'aguona'),
#  ('aguonpienis', 'aguona'),
#  ('aguonpienis', 'pienas'),
#  ('agurkas', 'agurkas'),
#  ('agurkėlis', 'agurkas'),
#  ('aidu', 'aidas'),
#  ('aikčiot', 'aikčioti'),
#  ('aikčioti', 'aikčioti'),
#  ('aikjų', 'aikjų'),
#  ('aikosas', 'aikosas'),
#  ('aikštėn', 'aikštė'),
#  ('aiškiaregys', 'aišku'),
#  ('aiškiaregys', 'regėti'),
#  ('aišku', 'aišku'),
#  ('aistringai', 'aistra'),
#  ('aistringo', 'aistra'),
#  ('aistruolis', 'aistra'),
#  ('aitvarai', 'aitvaras'),
#  ('aitvaras', 'aitvaras'),
#  ('akacija', 'akacija'),
#  ('akis', 'akis'),
#  ('akių', 'akis'),
#  ('akivaizdu', 'akivaizdu'),
#  ('aklas', 'aklas'),
#  ('aklus', 'aklas'),
#  ('akmenim', 'akmuo'),
#  ('akmuo', 'akmuo'),
#  ('akordeonas', 'akordeonas'),
#  ('akordu', 'akordas'),
#  ('aktyvus', 'aktyvus'),
#  ('akumas', 'akumuliatorius'),
#  ('akutes', 'akis'),
#  ('akutės', 'akis'),
#  ('akvalangą', 'akvalangas'),
#  ('akvalangas', 'akvalangas'),
#  ('akys', 'akis'),
#  ('alekas', 'alus'),
#  ('alfa', 'alfa'),
#  ('aliejingo', 'aliejus'),
#  ('aliejus', 'aliejus'),
#  ('alimentai', 'alimentai'),
#  ('aliuminis', 'aliuminis'),
#  ('alkaridas', 'alkaridas'),
#  ('alkoholis', 'alkoholis'),
#  ('alpės', 'alpės'),
#  ('aludė', 'alus'),
#  ('ąluolaskelmužės', 'ąžuolas'),
#  ('ąluolaskelmužės', 'kelmužė'),
#  ('alus', 'alus'),
#  ('alzheimeris', 'alzheimeris'),
#  ('amarai', 'amaras'),
#  ('ambicingo', 'ambicija'),
#  ('ameno', 'amen'),
#  ('amerikietis', 'amerika'),
#  ('aminorūgštis', 'rūgštis'),
#  ('amoniakas', 'amoniakas'),
#  ('amortizacija', 'amortizuoti'),
#  ('ampermetras', 'amperas'),
#  ('ampermetras', 'metras'),
#  ('amplitudė', 'amplitudė'),
#  ('amūras', 'amūras'),
#  ('amūrostrėle', 'amūras'),
#  ('amūrostrėle', 'strėlė'),
#  ('amūrostrėlė', 'amūras'),
#  ('amūrostrėlė', 'strėlė'),
#  ('amžinas', 'amžinas'),
#  ('anakonda', 'anakonda'),
#  ('analitinis', 'analizė'),
#  ('anatomija', 'anatomija'),
#  ('andrėtrykei', 'andrė'),
#  ('andrėtrykei', 'trys'),
#  ('andrėtrykei', 'tūkstantis'),
#  ('anginas', 'angina'),
#  ('angliakasis', 'anglis'),
#  ('angliakasis', 'kasti'),
#  ('angliesmonoksidas', 'anglis'),
#  ('angliesmonoksidas', 'oksidas'),
#  ('angliesmonoksidas', 'mono'),
#  ('anglinas', 'anglis'),
#  ('anglis', 'anglis'),
#  ('anilinas', 'anilinas'),
#  ('ankštis', 'ankštis'),
#  ('anšakospasikoręs', 'šaka'),
#  ('anšakospasikoręs', 'kartis'),
#  ('antakiai', 'antakiai'),
#  ('antanoguogos', 'antanasguoga'),
#  ('antinas', 'antis'),
#  ('antiseptikas', 'anti'),
#  ('antiseptikas', 'antiseptikas'),
#  ('antivakseris', 'vakcina'),
#  ('antivakseris', 'anti'),
#  ('antpuolis', 'pulti'),
#  ('antropologas', 'antropologas'),
#  ('antropologas', 'logos'),
#  ('antsuolis', 'suolas'),
#  ('anyžiai', 'anyžius'),
#  ('anyžinisliofantas', 'anyžius'),
#  ('anyžinisliofantas', 'liofantas'),
#  ('anyžius', 'anyžius'),
#  ('anžolėsnulūžęs', 'žolė'),
#  ('anžolėsnulūžęs', 'lūžti'),
#  ('aorta', 'aorta'),
#  ('apakau', 'apakti'),
#  ('apakęs', 'apakti'),
#  ('apakt', 'apakti'),
#  ('apanka', 'apakti'),
#  ('aparatas', 'aparatas'),
#  ('apatines', 'apačia'),
#  ('apatiniais', 'apačia'),
#  ('apatinius', 'apačia'),
#  ('apdriskęs', 'driskius'),
#  ('apetitas', 'apetitas'),
#  ('apgailėtinas', 'apgailėtinas'),
#  ('apgaulingo', 'apgaulė'),
#  ('apkakotas', 'kakoti'),
#  ('apkartęs', 'karsti'),
#  ('apkaušis', 'kaušti'),
#  ('apleistaspastatas', 'apleisti'),
#  ('apleistaspastatas', 'pastatas'),
#  ('apmaudu', 'apmaudas'),
#  ('apmyžęs', 'myžti'),
#  ('apmyžis', 'myžti'),
#  ('aprdriskęs', 'driskius'),
#  ('apsimyžai', 'myžti'),
#  ('apsivijęs', 'vytis'),
#  ('apsivogęs', 'vogti'),
#  ('apsivoši', 'vožti'),
#  ('apsivoži', 'vožti'),
#  ('apsivožia', 'vožti'),
#  ('apskritimas', 'apskritimas'),
#  ('aptingo', 'tinginys'),
#  ('aptingom', 'tinginys'),
#  ('aptingot', 'tinginys'),
#  ('apvoši', 'vožti'),
#  ('apvožia', 'vožti'),
#  ('arba', 'arba'),
#  ('arbaletas', 'arbaletas'),
#  ('arbata', 'arbata'),
#  ('arbatosmaišelis', 'arbata'),
#  ('arbatosmaišelis', 'maišas'),
#  ('arbūzą', 'arbūzas'),
#  ('arbūzas', 'arbūzas'),
#  ('architektas', 'architektas'),
#  ('architektūra', 'architektūra'),
#  ('arka', 'arka'),
#  ('arkada', 'arkada'),
#  ('arkada', 'kada'),
#  ('arki', 'arti'),
#  ('arkliukas', 'arklys'),
#  ('arkliuko', 'arklys'),
#  ('arklys', 'arklys'),
#  ('aromatingo', 'aromatas'),
#  ('arsnaiperis', 'snaiperis'),
#  ('arterija', 'arterija'),
#  ('arterijos', 'arterija'),
#  ('arti', 'arti'),
#  ('artibetbecigaro', 'arti'),
#  ('artibetbecigaro', 'cigaras'),
#  ('artifaktas', 'artifaktas'),
#  ('artifakto', 'artifaktas'),
#  ('artišoka', 'arti'),
#  ('artišoka', 'šokti'),
#  ('artritas', 'artritas'),
#  ('aruodai', 'aruodas'),
#  ('aruodu', 'aruodas'),
#  ('aš', 'aš'),
#  ('ašakos', 'ašaka'),
#  ('asalamaleikum', 'asalamaleikum'),
#  ('ašara', 'ašara'),
#  ('ašaros', 'ašara'),
#  ('asas', 'asas'),
#  ('asilas', 'asilas'),
#  ('asilųpulkožynys', 'asilas'),
#  ('asilųpulkožynys', 'pulkas'),
#  ('asilųpulkožynys', 'žynys'),
#  ('aširtu', 'aš'),
#  ('aširtu', 'tu'),
#  ('ašis', 'ašis'),
#  ('ašmenys', 'ašmenys'),
#  ('aspera', 'aspera'),
#  ('astralinėprojekcija', 'astralas'),
#  ('astralinėprojekcija', 'projekcija'),
#  ('aštriojikirsna', 'aštrus'),
#  ('aštriojikirsna', 'kirsna'),
#  ('aštrus', 'aštrus'),
#  ('aštuoni', 'aštuoni'),
#  ('ataka', 'ataka'),
#  ('ataspara', 'ataspara'),
#  ('atčiuoši', 'čiuožti'),
#  ('atdaras', 'daryti'),
#  ('ateiti', 'eiti'),
#  ('atidumo', 'atidumas'),
#  ('atiduodu', 'duoti'),
#  ('atidžiai', 'atidus'),
#  ('atidžiai', 'atidumas'),
#  ('atlėpausis', 'ausis'),
#  ('atlėpausis', 'lėpti'),
#  ('atletas', 'atletas'),
#  ('atmata', 'atmata'),
#  ('atmata', 'mesti'),
#  ('atmintieskortelę', 'atmintis'),
#  ('atmintieskortelę', 'korta'),
#  ('atmosfera', 'atmosfera'),
#  ('atomas', 'atomas'),
#  ('atomazga', 'atomazga'),
#  ('atomazga', 'megzti'),
#  ('atomazgos', 'atomazga'),
#  ('atomazgos', 'megzti'),
#  ('atostogas', 'atostogos'),
#  ('atostogos', 'atostogos'),
#  ('atpildu', 'atpildas'),
#  ('atpildu', 'pildyti'),
#  ('atrakinęs', 'rakinti'),
#  ('atrakinęs', 'raktas'),
#  ('atrakint', 'rakinti'),
#  ('atrakint', 'raktas'),
#  ('atrandu', 'rasti'),
#  ('atrodo', 'rodyti'),
#  ('atrodo', 'atrodyti'),
#  ('atrodžiau', 'rodyti'),
#  ('atrodžiau', 'atrodyti'),
#  ('atsakingo', 'atsakingas'),
#  ('atsigrūdu', 'grūsti'),
#  ('atsikvoši', 'kvošėtis'),
#  ('atsilieku', 'atsilikti'),
#  ('atsilieku', 'likti'),
#  ('atsilošę', 'loštis'),
#  ('atsiloši', 'loštis'),
#  ('atsilošia', 'loštis'),
#  ('atsilošiu', 'loštis'),
#  ('atsiprašau', 'atsiprašymas'),
#  ('atsiprašau', 'atsiprašyti'),
#  ('atsisukęs', 'sukti'),
#  ('atstumo', 'atstumas'),
#  ('atsuktuvas', 'atsuktuvas'),
#  ('atšutęs', 'šusti'),
#  ('atšvaitas', 'šviesti'),
#  ('atšvaitas', 'atšvaitas'),
#  ('atvarai', 'varyti'),
#  ('atvirutės', 'atvirutė'),
#  ('atvirutės', 'atviras'),
#  ('atvoži', 'vožti'),
#  ('atvykom', 'vykti'),
#  ('audi', 'audi'),
#  ('audinė', 'audi'),
#  ('audinė', 'audinė'),
#  ('audra', 'audra'),
#  ('audringo', 'audra'),
#  ('augalai', 'augalas'),
#  ('augalai', 'augti'),
#  ('augalas', 'augalas'),
#  ('augalas', 'augti'),
#  ('augalotas', 'augti'),
#  ('auginti', 'augti'),
#  ('auksas', 'auksas'),
#  ('auksiniukardu', 'auksas'),
#  ('auksiniukardu', 'kardas'),
#  ('aukšlės', 'aukšlė'),
#  ('aukštis', 'aukštas'),
#  ('aulas', 'aulas'),
#  ('auroraborealis', 'aurora'),
#  ('ausy', 'ausis'),
#  ('ausys', 'ausis'),
#  ('automobilis', 'automobilis'),
#  ('autoritetingo', 'autoritetas'),
#  ('avėjęs', 'avėti'),
#  ('aveliūganymą', 'avis'),
#  ('aveliūganymą', 'ganyti'),
#  ('aveliųganymas', 'avis'),
#  ('aveliųganymas', 'ganyti'),
#  ('avėti', 'avėti'),
#  ('avėtinas', 'avėti'),
#  ('avilys', 'avilys'),
#  ('aviukasšonas', 'avis'),
#  ('aviukasšonas', 'šonas'),
#  ('ąžuolaskelmužės', 'ąžuolas'),
#  ('ąžuolaskelmužės', 'kelmužė'),
#  ('baba', 'baba'),
#  ('babas', 'baba'),
#  ('babytė', 'baba'),
#  ('badarai', 'badaras'),
#  ('badaras', 'badaras'),
#  ('badu', 'badas'),
#  ('bagažas', 'bagažas'),
#  ('baidyklė', 'baidyti'),
#  ('baidys', 'baidyti'),
#  ('baidyti', 'baidyti'),
#  ('baigė', 'baigti'),
#  ('baika', 'bairis'),
#  ('baikas', 'bairis'),
#  ('bailys', 'baimė'),
#  ('baimingo', 'baimė'),
#  ('baisu', 'baisus'),
#  ('baklažanas', 'baklažanas'),
#  ('baksas', 'baksas'),
#  ('bakterija', 'bakterija'),
#  ('baladė', 'baladė'),
#  ('baladojas', 'baladoti'),
#  ('baladotis', 'baladoti'),
#  ('balamutras', 'balamutras'),
#  ('balandis', 'balandis'),
#  ('balas', 'bala'),
#  ('balastas', 'balastas'),
#  ('baletas', 'baletas'),
#  ('balionas', 'balionas'),
#  ('balnas', 'balnas'),
#  ('balsai', 'balsas'),
#  ('balsiai', 'balsas'),
#  ('balsingo', 'balsas'),
#  ('baltymas', 'baltymas'),
#  ('balus', 'balas'),
#  ('bambukas', 'bambukas'),
#  ('bananas', 'bananas'),
#  ('banas', 'banas'),
#  ('banda', 'banda'),
#  ('bandelė', 'banda'),
#  ('bandų', 'banda'),
#  ('bandžą', 'bandžas'),
#  ('banga', 'banga'),
#  ('bangą', 'banga'),
#  ('banglas', 'banglas'),
#  ('bangų', 'banga'),
#  ('bantas', 'bantas'),
#  ('barankas', 'baranka'),
#  ('barbaras', 'barbaras'),
#  ('barbė', 'barbė'),
#  ('barbėkenas', 'barbė'),
#  ('barbėkenas', 'kenas'),
#  ('barbęrado', 'barbė'),
#  ('barbęrado', 'rasti'),
#  ('barberis', 'barberis'),
#  ('bare', 'baras'),
#  ('baria', 'barti'),
#  ('barjeras', 'barjeras'),
#  ('barnis', 'barti'),
#  ('barsa', 'barselona'),
#  ('barščiai', 'barštis'),
#  ('barščiaiužvakarykščiai', 'barštis'),
#  ('barščiaiužvakarykščiai', 'vakar'),
#  ('barškėt', 'barškėti'),
#  ('barškėti', 'barškėti'),
#  ('barškuolė', 'barškėti'),
#  ('barsto', 'barstyti'),
#  ('basa', 'basas'),
#  ('basą', 'basas'),
#  ('baseinas', 'baseinas'),
#  ('baslį', 'baslys'),
#  ('basta', 'basta'),
#  ('bastytis', 'bastytis'),
#  ('basutes', 'basutė'),
#  ('basutės', 'basutė'),
#  ('batai', 'batas'),
#  ('batareikom', 'baterija'),
#  ('batarkės', 'baterija'),
#  ('batas', 'batas'),
#  ('baterija', 'baterija'),
#  ('batus', 'batas'),
#  ('batutas', 'batutas'),
#  ('baubas', 'baubas'),
#  ('bauda', 'bauda'),
#  ('baugu', 'baugus'),
#  ('bausis', 'bausti'),
#  ('bazaras', 'bazaras'),
#  ('bažnyčia', 'bažnyčia'),
#  ('beausis', 'ausis'),
#  ('bebenčiukas', 'bebenčiukas'),
#  ('bėda', 'bėda'),
#  ('bedančius', 'bedantis'),
#  ('bedantis', 'dantis'),
#  ('bedarbis', 'darbas'),
#  ('bėdos', 'bėda'),
#  ('bedugnė', 'dugnas'),
#  ('beduinas', 'beduinas'),
#  ('bedūšis', 'dūšia'),
#  ('bėemvė', 'bėemvė'),
#  ('begalė', 'begalė'),
#  ('begalė', 'galas'),
#  ('begalybė', 'begalė'),
#  ('begalybė', 'galas'),
#  ('bėgiai', 'bėgiai'),
#  ('bėgiai', 'bėgti'),
#  ('bėgti', 'bėgti'),
#  ('beigelis', 'beigelis'),
#  ('beisikeiliadarys', 'eilė'),
#  ('beisikeiliadarys', 'daryti'),
#  ('bekas', 'bekas'),
#  ('beleką', 'belenkas'),
#  ('belekas', 'belenkas'),
#  ('belenką', 'belenkas'),
#  ('belęšis', 'lęšis'),
#  ('bels', 'belsti'),
#  ('bembis', 'bembis'),
#  ('bemvas', 'bemvas'),
#  ('benamis', 'namas'),
#  ('bene', 'bene'),
#  ('benzinas', 'benzinas'),
#  ('bereikalingo', 'reikėti'),
#  ('beretė', 'beretė'),
#  ('bėri', 'bėras'),
#  ('bėriau', 'berti'),
#  ('beribiai', 'riba'),
#  ('beribų', 'riba'),
#  ('berniukas', 'bernas'),
#  ('bet', 'bet'),
#  ('beta', 'beta'),
#  ('bezdėt', 'bezdėti'),
#  ('bezdėti', 'bezdėti'),
#  ('bezdu', 'bezdėti'),
#  ('beždžionės', 'beždžionė'),
#  ('beždžionint', 'beždžionė'),
#  ('bičiųkaralienė', 'bitė'),
#  ('bičiųkaralienė', 'karalius'),
#  ('bidonas', 'bidonas'),
#  ('bigbong', 'bongas'),
#  ('biglezas', 'biglezas'),
#  ('bijai', 'bijoti'),
#  ('bijoti', 'bijoti'),
#  ('bildu', 'bildėti'),
#  ('biliardu', 'biliardas'),
#  ('bilietai', 'bilietas'),
#  ('bilietas', 'bilietas'),
#  ('bingbong', 'bing'),
#  ('bingbong', 'bong'),
#  ('bingo', 'bingo'),
#  ('bintas', 'bintas'),
#  ('birbinas', 'birbinti'),
#  ('birti', 'byrėti'),
#  ('birželis', 'birželis'),
#  ('bitas', 'bitas'),
#  ('bitė', 'bitė'),
#  ('bitinas', 'bitė'),
#  ('biustas', 'biustas'),
#  ('blaivas', 'blaivas'),
#  ('blakės', 'blakė'),
#  ('bliuzas', 'bliuzas'),
#  ('blizginti', 'blizgėti'),
#  ('bloga', 'blogas'),
#  ('blogapranašystė', 'blogas'),
#  ('blogapranašystė', 'pranašystė'),
#  ('blogas', 'blogas'),
#  ('blogasryšys', 'blogas'),
#  ('blogasryšys', 'ryšys'),
#  ('blogis', 'blogas'),
#  ('blusos', 'blusa'),
#  ('blynas', 'blynas'),
#  ('boba', 'boba'),
#  ('bobausis', 'boba'),
#  ('bobausis', 'ausis'),
#  ('bobausis', 'bobausis'),
#  ('bobslėjus', 'bobslėjus'),
#  ('bobulė', 'boba'),
#  ('bobutė', 'boba'),
#  ('bobyfišer', 'bobisfišeris'),
#  ('bokalas', 'bokalas'),
#  ('boksas', 'boksas'),
#  ('bokso', 'boksas'),
#  ('bokštas', 'bokštas'),
#  ('bolidu', 'bolidas'),
#  ('bolidų', 'bolidas'),
#  ('bolivinėbalanda', 'bolivija'),
#  ('bolivinėbalanda', 'balanda'),
#  ('bolivinesbalandas', 'bolivija'),
#  ('bolivinesbalandas', 'balanda'),
#  ('boliviniubalandu', 'bolivija'),
#  ('boliviniubalandu', 'balanda'),
#  ('boliviniųbalandų', 'bolivija'),
#  ('boliviniųbalandų', 'balanda'),
#  ('bomba', 'bomba'),
#  ('bombioškė', 'bomba'),
#  ('bombom', 'bomba'),
#  ('bombonešis', 'bomba'),
#  ('bombonešis', 'nešti'),
#  ('bombonešis', 'bombonešis'),
#  ('bonbon', 'bonbonkė'),
#  ('bonbonkė', 'bonbonkė'),
#  ('bonbonkėm', 'bonbonkė'),
#  ('bongas', 'bongas'),
#  ('bongo', 'bongas'),
#  ('bongovanduo', 'bongas'),
#  ('bonkė', 'butelis'),
#  ('bonobas', 'bonobas'),
#  ('bonus', 'bonus'),
#  ('bonžur', 'bonžur'),
#  ('boras', 'boras'),
#  ('boratas', 'boratas'),
#  ('bordo', 'bordo'),
#  ('bortas', 'bortas'),
#  ('boš', 'boš'),
#  ('braletė', 'braletė'),
#  ('brandu', 'brandus'),
#  ('brangakmenis', 'brangus'),
#  ('brangakmenis', 'akmuo'),
#  ('brangakmenis', 'brangakmenis'),
#  ('brangu', 'brangus'),
#  ('branguolis', 'brangus'),
#  ('brangus', 'brangus'),
#  ('brangusistulavonas', 'brangus'),
#  ('brangusistulavonas', 'lavonas'),
#  ('brangusistulavonas', 'tu'),
#  ('braškė', 'braškė'),
#  ('braškės', 'braškė'),
#  ('braukei', 'braukti'),
#  ('brauningo', 'brauningas'),
#  ('brautis', 'brautis'),
#  ('bravo', 'bravo'),
#  ('brazauskas', 'algirdasbrazauskas'),
#  ('brazausko', 'algirdasbrazauskas'),
#  ('brazda', 'brazdėti'),
#  ('brazdėt', 'brazdėti'),
#  ('brazdėti', 'brazdėti'),
#  ('breketai', 'breketai'),
#  ('brendu', 'bristi'),
#  ('brezentas', 'brezentas'),
#  ('bridžas', 'bridžas'),
#  ('briedas', 'briedas'),
#  ('briedis', 'briedis'),
#  ('briusly', 'briusly'),
#  ('broliai', 'brolis'),
#  ('bruožas', 'bruožas'),
#  ('bruože', 'bruožas'),
#  ('bružas', 'andriusbružas'),
#  ('brūžys', 'brūžinti'),
#  ('bubis', 'bubis'),
#  ('bučkis', 'bučinys'),
#  ('būdas', 'būdas'),
#  ('būdingoj', 'būdas'),
#  ('būdingom', 'būdas'),
#  ('būdingos', 'būdas'),
#  ('budulis', 'budulis'),
#  ('būgną', 'būgnas'),
#  ('būgnai', 'būgnas'),
#  ('bukas', 'bukas'),
#  ('bukės', 'bukas'),
#  ('bukumo', 'bukas'),
#  ('buldogas', 'bulius'),
#  ('buldogas', 'šuo'),
#  ('buldogas', 'buldogas'),
#  ('bulijonas', 'bulijonas'),
#  ('bulka', 'bulka'),
#  ('bulvė', 'bulvė'),
#  ('bulvėstarkis', 'bulvė'),
#  ('bulvėstarkis', 'tarkis'),
#  ('bulviųsalotos', 'bulvė'),
#  ('bulviųsalotos', 'salota'),
#  ('bumerangas', 'bumerangas'),
#  ('būna', 'būti'),
#  ('bunda', 'busti'),
#  ('bundu', 'busti'),
#  ('bunkeris', 'bunkeris'),
#  ('būnu', 'būti'),
#  ('buože', 'buožė'),
#  ('buožė', 'buožė'),
#  ('buožę', 'buožė'),
#  ('buožės', 'buožė'),
#  ('būras', 'būras'),
#  ('buratinas', 'buratinas'),
#  ('burba', 'burbėti'),
#  ('burė', 'burė'),
#  ('burės', 'burė'),
#  ('buridanoasilas', 'asilas'),
#  ('burių', 'burė'),
#  ('burna', 'burna'),
#  ('burną', 'burna'),
#  ('burokinėtarka', 'burokas'),
#  ('burokinėtarka', 'tarka'),
#  ('burti', 'burti'),
#  ('bus', 'būti'),
#  ('bustas', 'būti'),
#  ('butas', 'butas'),
#  ('bute', 'butas'),
#  ('butelys', 'butelis'),
#  ('būti', 'būti'),
#  ('būtinas', 'būtinas'),
#  ('būty', 'būtis'),
#  ('būty', 'būty'),
#  ('buvau', 'būti'),
#  ('buvęs', 'būti'),
#  ('būžis', 'būžys'),
#  ('būžys', 'būžys'),
#  ('bybis', 'bybys'),
#  ('byla', 'byla'),
#  ('caras', 'caras'),
#  ('čeburėkas', 'čeburėkas'),
#  ('čėdinti', 'čėdinti'),
#  ('cedrikas', 'cedrikas'),
#  ('cėketuri', 'keturi'),
#  ('čekis', 'čekis'),
#  ('čekuolis', 'algimantasčekuolis'),
#  ('celiulioidu', 'celiuliozė'),
#  ('celiuliozė', 'celiuliozė'),
#  ('celiulitas', 'celiulitas'),
#  ('cepelinas', 'cepelinas'),
#  ('česnakinis', 'česnakas'),
#  ('chalapa', 'chalapa'),
#  ('chalatas', 'chalatas'),
#  ('chalate', 'chalatas'),
#  ('chalato', 'chalatas'),
#  ('chaosas', 'chaosas'),
#  ('charakteringo', 'charakteris'),
#  ('chavinimas', 'chavinti'),
#  ('chemikalas', 'chemija'),
#  ('chloroformas', 'chloras'),
#  ('choras', 'choras'),
#  ('čia', 'čia'),
#  ('čiaupaprašyt', 'prašyti'),
#  ('cicinas', 'cicinas'),
#  ('ciela', 'cielas'),
#  ('cielą', 'cielas'),
#  ('cigaras', 'cigaras'),
#  ('cigaretė', 'cigaretė'),
#  ('čigonas', 'čigonas'),
#  ('čihuahua', 'čihuahua'),
#  ('ciklonas', 'ciklas'),
#  ('čili', 'čili'),
#  ('cinamonas', 'cinamonas'),
#  ('cingolas', 'cingolas'),
#  ('cirkas', 'cirkas'),
#  ('čirškėti', 'čirškėti'),
#  ('čirvai', 'čirvas'),
#  ('citrinas', 'citrina'),
#  ('citrinos', 'citrina'),
#  ('citrinų', 'citrina'),
#  ('citrusinis', 'citrusas'),
#  ('čiulpėdra', 'čiulpėdra'),
#  ('čiuoži', 'čiuožti'),
#  ('čiuožia', 'čiuožti'),
#  ('čiuožti', 'čiuožti'),
#  ('čiūr', 'čiuras'),
#  ('čiuras', 'čiuras'),
#  ('čiurinas', 'čiuras'),
#  ('čiurlys', 'čiurlys'),
#  ('čiurna', 'čiurna'),
#  ('čiurną', 'čiurna'),
#  ('cizas', 'cigaretė'),
#  ('cololo', 'vitalijuscololo'),
#  ('combo', 'kombinacija'),
#  ('cukrinas', 'cukrus'),
#  ('cukrinė', 'cukrus'),
#  ('cukrinis', 'cukrus'),
#  ('cunamis', 'cunamis'),
#  ('dabar', 'dabar'),
#  ('dabarmane', 'dabar'),
#  ('dabarmane', 'aš'),
#  ('daboti', 'daboti'),
#  ('dabotikaipugnį', 'daboti'),
#  ('dabotikaipugnį', 'ugnis'),
#  ('dabotikapugnį', 'daboti'),
#  ('dabotikapugnį', 'ugnis'),
#  ('dagtis', 'dagtis'),
#  ('dagtys', 'dagtis'),
#  ('daigas', 'daigas'),
#  ('daiktas', 'daiktas'),
#  ('dainai', 'daina'),
#  ('daktaras', 'daktaras'),
#  ('dalus', 'dalinti'),
#  ('danga', 'danga'),
#  ('danga', 'dengti'),
#  ('dangtis', 'dangtis'),
#  ('dangtis', 'dengti'),
#  ('dangus', 'dangus'),
#  ('dantis', 'dantis'),
#  ('dantųkrapštukas', 'dantis'),
#  ('dantųkrapštukas', 'krapštukas'),
#  ('dantųkrapštukas', 'krapštyti'),
#  ('dantys', 'dantis'),
#  ('darantnesigavo', 'daryti'),
#  ('darantnesigavo', 'gauti'),
#  ('darbinas', 'darbas'),
#  ('darbingo', 'darbas'),
#  ('darbokėdė', 'darbas'),
#  ('darbokėdė', 'kėdė'),
#  ('darbštuolis', 'darbas'),
#  ('dardu', 'dardėti'),
#  ('dariusirgirėnas', 'dariusirgirėnas'),
#  ('darko', 'dar'),
#  ('darko', 'kas'),
#  ('darogas', 'daroga'),
#  ('darogienės', 'daroga'),
#  ('daroginis', 'daroga'),
#  ('daros', 'daryti'),
#  ('darto', 'dar'),
#  ('darto', 'tas'),
#  ('dartų', 'dartai'),
#  ('daruogienės', 'uogienė'),
#  ('daryt', 'daryti'),
#  ('daryti', 'daryti'),
#  ('daržove', 'daržovė'),
#  ('daržovė', 'daržovė'),
#  ('daržovėiškrautuvės', 'daržovė'),
#  ('daržovėiškrautuvės', 'krautuvė'),
#  ('daržovėišrauta', 'daržovė'),
#  ('daržovėišrauta', 'rauti'),
#  ('data', 'data'),
#  ('dauči', 'dauči'),
#  ('daug', 'daug'),
#  ('daužo', 'daužyti'),
#  ('daužyt', 'daužyti'),
#  ('daužyti', 'daužyti'),
#  ('daviklis', 'duoti'),
#  ('daviklis', 'daviklis'),
#  ('dažai', 'dažai'),
#  ('dažai', 'dažyti'),
#  ('dažasvydis', 'dažasvydis'),
#  ('dažnas', 'dažnas'),
#  ('dažnis', 'dažnis'),
#  ('dažyt', 'dažyti'),
#  ('dažyti', 'dažyti'),
#  ('debesėlis', 'debesis'),
#  ('debesingo', 'debesis'),
#  ('debesis', 'debesis'),
#  ('debesy', 'debesis'),
#  ('debesys', 'debesis'),
#  ('debiutantas', 'debiutas'),
#  ('debiutas', 'debiutas'),
#  ('dedekindopjūvis', 'pjūvis'),
#  ('dedu', 'dėti'),
#  ('dėener', 'dėener'),
#  ('defakto', 'defakto'),
#  ('deformuotigabalai', 'deformuoti'),
#  ('deformuotigabalai', 'gabalas'),
#  ('deglas', 'deglas'),
#  ('degradacija', 'degraduoti'),
#  ('degs', 'degti'),
#  ('degt', 'degti'),
#  ('degti', 'degti'),
#  ('degtukas', 'degti'),
#  ('degutas', 'degutas'),
#  ('deimantas', 'deimantas'),
#  ('dėkingo', 'dėkoti'),
#  ('dėkingoj', 'dėkoti'),
#  ('dėkingom', 'dėkoti'),
#  ('dėkingos', 'dėktoi'),
#  ('dėlė', 'dėlė'),
#  ('delfinas', 'delfinas'),
#  ('delnas', 'delnas'),
#  ('delyras', 'delyras'),
#  ('demagogas', 'demagogija'),
#  ('dėmės', 'dėmė'),
#  ('dėmesingo', 'dėmesys'),
#  ('dėmesio', 'dėmesys'),
#  ('demonas', 'demonas'),
#  ('dėmuo', 'dėmuo'),
#  ('denis', 'denis'),
#  ('depozitas', 'depozitas'),
#  ('derėti', 'derėti'),
#  ('derinas', 'derinti'),
#  ('dervos', 'dervos'),
#  ('dešimt', 'dešimt'),
#  ('dešine', 'dešinė'),
#  ('dešinė', 'dešinė'),
#  ('dešinę', 'dešinė'),
#  ('dėsningo', 'dėsnis'),
#  ('despacito', 'despasito'),
#  ('despasyto', 'despasito'),
#  ('dešra', 'dešra'),
#  ('dešrelė', 'dešra'),
#  ('dėtą', 'dėti'),
#  ('dėti', 'dėti'),
#  ('detonatorius', 'detonuoti'),
#  ('dėvėti', 'dėvėti'),
#  ('devyni', 'devyni'),
#  ('dežavu', 'dežavu'),
#  ('dėžutė', 'dėžė'),
#  ('dėžutės', 'dėžė'),
#  ('diagnostinis', 'diagnozė'),
#  ('dialogas', 'dialogas'),
#  ('diaunlau', 'diaunlau'),
#  ('didelis', 'didelis'),
#  ('didikas', 'didus'),
#  ('didingoj', 'didus'),
#  ('didingom', 'didus'),
#  ('didingos', 'didus'),
#  ('didu', 'didus'),
#  ('didžitaltek', 'tek'),
#  ('didžitaltek', 'didžital'),
#  ('dievobaimingo', 'dievas'),
#  ('dievobaimingo', 'baimė'),
#  ('dikcija', 'diktuoti'),
#  ('diklakgelis', 'gelis'),
#  ('diktantas', 'diktantas'),
#  ('diletantas', 'diletantas'),
#  ('dilginti', 'dilgėlė'),
#  ('dilti', 'dilti'),
#  ('dinamitas', 'dinamitas'),
#  ('dindilindi', 'dindilindi'),
#  ('dingo', 'dingti'),
#  ('dingojo', 'dingoti'),
#  ('dingsiu', 'dingti'),
#  ('dingt', 'dingti'),
#  ('dingti', 'dingti'),
#  ('dirbai', 'dirbti'),
#  ('dirbti', 'dirbti'),
#  ('dirigentas', 'dirigentas'),
#  ('dirvai', 'dirva'),
#  ('dirvos', 'dirva'),
#  ('dirvožemis', 'dirva'),
#  ('dirvožemis', 'žemė'),
#  ('dirvožemis', 'dirvožemis'),
#  ('dirvožemy', 'dirva'),
#  ('dirvožemy', 'žemė'),
#  ('dirvožemy', 'dirvožemis'),
#  ('diskas', 'diskas'),
#  ('dišova', 'dišovas'),
#  ('dišovi', 'dišovas'),
#  ('ditirambas', 'ditirambas'),
#  ('dizainas', 'dizainas'),
#  ('dobermanas', 'dobermanas'),
#  ('dobermane', 'dobermanas'),
#  ('dobilas', 'dobilas'),
#  ('doechii', 'dauči'),
#  ('dogas', 'šuo'),
#  ('domino', 'domino'),
#  ('dopingo', 'dopingas'),
#  ('doras', 'doras'),
#  ('doratyeksplora', 'doratyeksplora'),
#  ('dorovė', 'doras'),
#  ('dorybingo', 'doras'),
#  ('dozė', 'dozė'),
#  ('drabužiai', 'drabužis'),
#  ('drakula', 'drakula'),
#  ('dramblys', 'dramblys'),
#  ('drąsuolis', 'drąsus'),
#  ('drausmingo', 'drausmė'),
#  ('draustinis', 'draustinis'),
#  ('draustinis', 'drausti'),
#  ('drogas', 'drogas'),
#  ('droši', 'drožti'),
#  ('droži', 'drožti'),
#  ('drožia', 'drožti'),
#  ('drožiu', 'drožti'),
#  ('drožti', 'drožti'),
#  ('drožyba', 'drožti'),
#  ('dručkis', 'dručkis'),
#  ('drugelis', 'drugys'),
#  ('drugys', 'drugys'),
#  ('druska', 'druska'),
#  ('drybsau', 'drybsoti'),
#  ('dryžius', 'dryžius'),
#  ('du', 'du'),
#  ('dubuo', 'dubuo'),
#  ('dūdmaišio', 'dūda'),
#  ('dūdmaišio', 'maišas'),
#  ('dūdmaišio', 'dūdmaišis'),
#  ('dūdmaišis', 'dūdmaišis'),
#  ('dūdų', 'dūda'),
#  ('duetas', 'duetas'),
#  ('dugną', 'dugnas'),
#  ('dugnai', 'dugnas'),
#  ('dūkęs', 'dūkti'),
#  ('dulka', 'dulkė'),
#  ('dulkės', 'dulkė'),
#  ('dulkėti', 'dulkė'),
#  ('dulkinas', 'dulkė'),
#  ('dūmai', 'dūmai'),
#  ('dūmas', 'dūmai'),
#  ('dūmųdaviklis', 'dūmai'),
#  ('dūmųdaviklis', 'daviklis'),
#  ('dūmųdaviklis', 'duoti'),
#  ('dunda', 'dundėti'),
#  ('dundėti', 'dundėti'),
#  ('dundu', 'dundėti'),
#  ('dundulis', 'dundulis'),
#  ('duodas', 'duoti'),
#  ('duodu', 'duoti'),
#  ('duokdu', 'duoti'),
#  ('duokdu', 'du'),
#  ('duoklė', 'duoti'),
#  ('duoklė', 'duoklė'),
#  ('duona', 'duona'),
#  ('duoningo', 'duona'),
#  ('duoti', 'duona'),
#  ('dūra', 'dūra'),
#  ('dūrė', 'durti'),
#  ('dūrį', 'durti'),
#  ('duris', 'durys'),
#  ('dūris', 'durti'),
#  ('durys', 'durys'),
#  ('dušas', 'dušas'),
#  ('dusliai', 'duslus'),
#  ('dūsti', 'dūsti'),
#  ('dusulys', 'dūsti'),
#  ('dūžis', 'dužti'),
#  ('dvare', 'dvaras'),
#  ('dvasingo', 'dvasia'),
#  ('dvejinas', 'du'),
#  ('dvejinasi', 'du'),
#  ('dvikairės', 'du'),
#  ('dvikairės', 'kairė'),
#  ('dvokas', 'dvokti'),
#  ('dvylikapirštė', 'dvylika'),
#  ('dvylikapirštė', 'piršas'),
#  ('dvylikapirštė', 'dvylikapirštė'),
#  ('dykuma', 'dykuma'),
#  ('dylas', 'dylas'),
#  ('dyvas', 'dyvas'),
#  ('dyvinas', 'dyvas'),
#  ('dyvųdyvas', 'dyvas'),
#  ('džemas', 'džemas'),
#  ('džiaugsmingo', 'džiaugsmas'),
#  ('džiazas', 'džiazas'),
#  ('dziegoriai', 'dziegorius'),
#  ('dziegoriaineveikia', 'dziegorius'),
#  ('dziegoriaineveikia', 'veikti'),
#  ('dziegorius', 'dziegorius'),
#  ('džimisneutronas', 'džimisneutronas'),
#  ('džiumandži', 'džiumandži'),
#  ('džiūt', 'džiūti'),
#  ('džiūti', 'džiūti'),
#  ('džonybravo', 'džonybravo'),
#  ('džonysins', 'džonysins'),
#  ('dzūkas', 'dzūkija'),
#  ('dzūkija', 'dzūkija'),
#  ('ėda', 'ėsti'),
#  ('ėdu', 'ėsti'),
#  ('efektas', 'efektas'),
#  ('efektyvus', 'efektas'),
#  ('eglė', 'eglė'),
#  ('eglutė', 'eglė'),
#  ('ego', 'ego'),
#  ('egzorcizmas', 'egzorcizmas'),
#  ('ei', 'ei'),
#  ('eigulys', 'eigulys'),
#  ('eiksau', 'eiti'),
#  ('eikščia', 'eiti'),
#  ('eikščia', 'čia'),
#  ('eis', 'eiti'),
#  ('eismas', 'eismas'),
#  ('eismas', 'eiti'),
#  ('eit', 'eiti'),
#  ('eiti', 'eiti'),
#  ('ėjo', 'eiti'),
#  ('ėjus', 'eiti'),
#  ('eketė', 'eketė'),
#  ('eketės', 'eketė'),
#  ('ekipažas', 'ekipažas'),
#  ('eksterjeras', 'eksterjeras'),
#  ('elanką', 'elanką'),
#  ('elasbandis', 'elasbandis'),
#  ('elasdė', 'elasdė'),
#  ('elastika', 'elastika'),
#  ('elastingo', 'elastika'),
#  ('elazdė', 'elazdė'),
#  ('elektra', 'elektra'),
#  ('elektrodu', 'elektra'),
#  ('elektronas', 'elektra'),
#  ('elgeta', 'elgeta'),
#  ('elgetausjis', 'elgeta'),
#  ('elgetausjis', 'jis'),
#  ('eliksyras', 'eliksyras'),
#  ('elipsė', 'elipsė'),
#  ('elitinis', 'elitas'),
#  ('elnias', 'elnias'),
#  ('emocingo', 'emocija'),
#  ('emsypydžeipurvinis', 'emsypydžeipurvinis'),
#  ('energingo', 'energija'),
#  ('engimas', 'engti'),
#  ('engti', 'engti'),
#  ('enkartų', 'kartas'),
#  ('entuziastingo', 'entuziazmas'),
#  ('enziukas', 'enzė'),
#  ('epilogas', 'epilogas'),
#  ('epušis', 'epušė'),
#  ('erdvė', 'erdvė'),
#  ('erekcija', 'erekcija'),
#  ('erelis', 'erelis'),
#  ('erikabadu', 'erikabadu'),
#  ('erkė', 'erkė'),
#  ('erškėčiai', 'erškėtis'),
#  ('erškėčių', 'erškėtis'),
#  ('erškėtingo', 'erškėtis'),
#  ('erškėtrože', 'erškėtis'),
#  ('erškėtrože', 'rožė'),
#  ('erškėtrože', 'erškėtrožė'),
#  ('erškėtrožę', 'erškėtis'),
#  ('erškėtrožę', 'rožė'),
#  ('erškėtrožę', 'erškėtrožė'),
#  ('ešerius', 'ešerys'),
#  ('ešerys', 'ešerys'),
#  ('esi', 'būti'),
#  ('esmėtokia', 'esmė'),
#  ('esmėtokia', 'toks'),
#  ('ėsti', 'ėsti'),
#  ('etapas', 'etapas'),
#  ('etika', 'etika'),
#  ('etiketės', 'etiketė'),
#  ('eucerinas', 'eucerinas'),
#  ('eufratasirtigras', 'tigrasireufratas'),
#  ...)

# %%
morphs = tuple(item[0] for item in to_core_pairs)

# %%
cur.execute(f'SELECT morph, id FROM morphs WHERE morph in %s', (morphs,))
morph_morph_id = cur.fetchall()

# %%
morph_to_morph_id = {item[0]: item[1] for item in morph_morph_id}

# %%
cores = tuple(item[1] for item in to_core_pairs)

# %%
cur.execute(f'SELECT core, id FROM cores WHERE core in %s', (cores,))
core_core_id = cur.fetchall()

# %%
core_to_core_id = {item[0]: item[1] for item in core_core_id}

# %%
the_thing = tuple((morph_to_morph_id[item[0]], core_to_core_id[item[1]]) for item in to_core_pairs)

# %%
cur.executemany(f'INSERT INTO morphs_cores (morph_id, core_id) VALUES (%s, %s) ON CONFLICT DO NOTHING', the_thing)
conn.commit()

# %%
core_to_core_id
# Out:
# {'daržovė': 397,
#  'rimas': 2176,
#  'gesti': 2658,
#  'krautuvė': 1076,
#  'ankštis': 5,
#  'baklažanas': 6,
#  'bulvė': 7,
#  'asilas': 8,
#  'amplitudė': 9,
#  'akvalangas': 10,
#  'akivaizdu': 11,
#  'alkaridas': 12,
#  'antiseptikas': 13,
#  'aorta': 14,
#  'architektas': 15,
#  'architektūra': 16,
#  'budulis': 17,
#  'bunkeris': 18,
#  'defakto': 19,
#  'dozė': 20,
#  'guoga': 21,
#  'gyvulys': 22,
#  'acetilakrilatas': 23,
#  'antropologas': 24,
#  'bobslėjus': 25,
#  'alimentai': 26,
#  'artifaktas': 27,
#  'arba': 28,
#  'baidyti': 29,
#  'balandis': 30,
#  'birželis': 31,
#  'alfa': 32,
#  'baltymas': 33,
#  'bedantis': 34,
#  'epilogas': 35,
#  'benzinas': 36,
#  'boratas': 37,
#  'boš': 38,
#  'haki': 39,
#  'karsti': 40,
#  'amžinas': 41,
#  'apetitas': 42,
#  'arbūzas': 43,
#  'arka': 44,
#  'banglas': 45,
#  'barbaras': 46,
#  'beretė': 47,
#  'buožė': 48,
#  'asas': 49,
#  'apgailėtinas': 50,
#  'amoniakas': 51,
#  'apskritimas': 52,
#  'akordeonas': 53,
#  'atletas': 54,
#  'bagažas': 55,
#  'bastytis': 56,
#  'abstraktus': 57,
#  'aikosas': 58,
#  'agurkas': 59,
#  'anakonda': 60,
#  'arbaletas': 61,
#  'adata': 62,
#  'fūra': 63,
#  'girlianda': 64,
#  'adrenalinas': 65,
#  'asalamaleikum': 66,
#  'ašmenys': 67,
#  'auksas': 68,
#  'bintas': 69,
#  'brautis': 70,
#  'čekis': 71,
#  'eglė': 72,
#  'engti': 73,
#  'erelis': 74,
#  'fontanas': 75,
#  'grandinė': 76,
#  'grilius': 77,
#  'inkaras': 78,
#  'kaliausė': 79,
#  'kandis': 80,
#  'kankorėžis': 81,
#  'kartoti': 82,
#  'kengūra': 83,
#  'kikflipas': 84,
#  'anglis': 85,
#  'anilinas': 86,
#  'antakiai': 87,
#  'antanasguoga': 88,
#  'antis': 89,
#  'anti': 90,
#  'liofantas': 91,
#  'anyžius': 92,
#  'apakti': 93,
#  'apačia': 94,
#  'apgaulė': 95,
#  'kakoti': 96,
#  'abejoti': 97,
#  'afganistanas': 98,
#  'afrodiziakas': 99,
#  'agnostika': 100,
#  'agreguoti': 101,
#  'aguona': 102,
#  'aidas': 103,
#  'aikčioti': 104,
#  'aikjų': 105,
#  'aikštė': 106,
#  'regėti': 107,
#  'aišku': 108,
#  'aistra': 109,
#  'aitvaras': 110,
#  'akacija': 111,
#  'aklas': 112,
#  'akordas': 113,
#  'akumuliatorius': 114,
#  'aliejus': 115,
#  'aliuminis': 116,
#  'alkoholis': 117,
#  'alpės': 118,
#  'alus': 119,
#  'alzheimeris': 120,
#  'amaras': 121,
#  'ambicija': 122,
#  'amen': 123,
#  'amerika': 124,
#  'amortizuoti': 125,
#  'amperas': 126,
#  'amūras': 127,
#  'analizė': 128,
#  'anatomija': 129,
#  'andrė': 130,
#  'tūkstantis': 131,
#  'angina': 132,
#  'apleisti': 133,
#  'apmaudas': 134,
#  'driskius': 135,
#  'vytis': 136,
#  'tinginys': 137,
#  'arbata': 138,
#  'arkada': 139,
#  'arklys': 140,
#  'aromatas': 141,
#  'arterija': 142,
#  'arti': 143,
#  'artritas': 144,
#  'aruodas': 145,
#  'ašaka': 146,
#  'ašara': 147,
#  'aspera': 148,
#  'astralas': 149,
#  'kirsna': 150,
#  'aštrus': 151,
#  'aštuoni': 152,
#  'ataka': 153,
#  'ataspara': 154,
#  'atidus': 155,
#  'atidumas': 156,
#  'lėpti': 157,
#  'atmata': 158,
#  'atmintis': 159,
#  'atmosfera': 160,
#  'atomas': 161,
#  'atomazga': 162,
#  'atostogos': 163,
#  'atpildas': 164,
#  'rodyti': 165,
#  'atrodyti': 166,
#  'kvošėtis': 167,
#  'atsilikti': 168,
#  'loštis': 169,
#  'atsiprašymas': 170,
#  'atsiprašyti': 171,
#  'atstumas': 172,
#  'atsuktuvas': 173,
#  'šviesti': 174,
#  'atšvaitas': 175,
#  'atvirutė': 176,
#  'atviras': 177,
#  'vykti': 178,
#  'audi': 179,
#  'audinė': 180,
#  'audra': 181,
#  'augalas': 182,
#  'augti': 183,
#  'aukšlė': 184,
#  'aulas': 185,
#  'aurora': 186,
#  'automobilis': 187,
#  'autoritetas': 188,
#  'avėti': 189,
#  'avilys': 190,
#  'avis': 191,
#  'ąžuolas': 192,
#  'kelmužė': 193,
#  'baba': 194,
#  'badaras': 195,
#  'badas': 196,
#  'baigti': 197,
#  'bairis': 198,
#  'baisus': 199,
#  'baksas': 200,
#  'bakterija': 201,
#  'baladė': 202,
#  'baladoti': 203,
#  'balamutras': 204,
#  'bala': 205,
#  'balastas': 206,
#  'baletas': 207,
#  'balionas': 208,
#  'balnas': 209,
#  'balsas': 210,
#  'balas': 211,
#  'bambukas': 212,
#  'bananas': 213,
#  'banas': 214,
#  'banda': 215,
#  'bandžas': 216,
#  'bantas': 217,
#  'baranka': 218,
#  'barbė': 219,
#  'barberis': 220,
#  'barjeras': 221,
#  'barti': 222,
#  'barselona': 223,
#  'barštis': 224,
#  'vakar': 225,
#  'barškėti': 226,
#  'barstyti': 227,
#  'baseinas': 228,
#  'baslys': 229,
#  'basta': 230,
#  'basutė': 231,
#  'baterija': 232,
#  'batas': 233,
#  'batutas': 234,
#  'baubas': 235,
#  'bauda': 236,
#  'baugus': 237,
#  'bausti': 238,
#  'bazaras': 239,
#  'bažnyčia': 240,
#  'bebenčiukas': 241,
#  'bėda': 242,
#  'beduinas': 243,
#  'dūšia': 244,
#  'bėemvė': 245,
#  'begalė': 246,
#  'bėgiai': 247,
#  'bėgti': 248,
#  'beigelis': 249,
#  'eilė': 250,
#  'bekas': 251,
#  'belenkas': 252,
#  'belsti': 253,
#  'bembis': 254,
#  'bemvas': 255,
#  'bene': 256,
#  'bėras': 257,
#  'bernas': 258,
#  'bet': 259,
#  'beta': 260,
#  'beždžionė': 261,
#  'bidonas': 262,
#  'biglezas': 263,
#  'bijoti': 264,
#  'bildėti': 265,
#  'biliardas': 266,
#  'bilietas': 267,
#  'bing': 268,
#  'bong': 269,
#  'bingo': 270,
#  'birbinti': 271,
#  'bitas': 272,
#  'bitė': 273,
#  'biustas': 274,
#  'blaivas': 275,
#  'blakė': 276,
#  'bliuzas': 277,
#  'blizgėti': 278,
#  'blusa': 279,
#  'blynas': 280,
#  'ausis': 281,
#  'bobausis': 282,
#  'boba': 283,
#  'bobisfišeris': 284,
#  'bokalas': 285,
#  'boksas': 286,
#  'bokštas': 287,
#  'bolidas': 288,
#  'bolivija': 289,
#  'balanda': 290,
#  'bomba': 291,
#  'bombonešis': 292,
#  'bonbonkė': 293,
#  'bongas': 294,
#  'bonobas': 295,
#  'bonus': 296,
#  'bonžur': 297,
#  'boras': 298,
#  'bordo': 299,
#  'bortas': 300,
#  'braletė': 301,
#  'brangakmenis': 302,
#  'brangus': 303,
#  'braškė': 304,
#  'braukti': 305,
#  'brauningas': 306,
#  'bravo': 307,
#  'breketai': 308,
#  'bristi': 309,
#  'brezentas': 310,
#  'bridžas': 311,
#  'briedas': 312,
#  'briedis': 313,
#  'briusly': 314,
#  'brolis': 315,
#  'bruožas': 316,
#  'andriusbružas': 317,
#  'brūžinti': 318,
#  'bubis': 319,
#  'bučinys': 320,
#  'bukas': 321,
#  'bulius': 322,
#  'buldogas': 323,
#  'bulijonas': 324,
#  'bulka': 325,
#  'bumerangas': 326,
#  'busti': 327,
#  'būras': 328,
#  'buratinas': 329,
#  'burbėti': 330,
#  'burė': 331,
#  'burokas': 332,
#  'burti': 333,
#  'butelis': 334,
#  'būtinas': 335,
#  'būtis': 336,
#  'būty': 337,
#  'būžys': 338,
#  'bybys': 339,
#  'byla': 340,
#  'caras': 341,
#  'čeburėkas': 342,
#  'čėdinti': 343,
#  'cedrikas': 344,
#  'algimantasčekuolis': 345,
#  'celiuliozė': 346,
#  'celiulitas': 347,
#  'cepelinas': 348,
#  'česnakas': 349,
#  'chalapa': 350,
#  'chalatas': 351,
#  'chaosas': 352,
#  'charakteris': 353,
#  'chavinti': 354,
#  'chemija': 355,
#  'choras': 356,
#  'cicinas': 357,
#  'cielas': 358,
#  'cigaras': 359,
#  'čigonas': 360,
#  'čihuahua': 361,
#  'ciklas': 362,
#  'čili': 363,
#  'cinamonas': 364,
#  'cingolas': 365,
#  'cirkas': 366,
#  'čirškėti': 367,
#  'čirvas': 368,
#  'citrina': 369,
#  'citrusas': 370,
#  'čiulpėdra': 371,
#  'čiuras': 372,
#  'čiurlys': 373,
#  'čiurna': 374,
#  'cigaretė': 375,
#  'vitalijuscololo': 376,
#  'cukrus': 377,
#  'cunamis': 378,
#  'dabar': 379,
#  'daboti': 380,
#  'dagtis': 381,
#  'daigas': 382,
#  'daiktas': 383,
#  'daina': 384,
#  'daktaras': 385,
#  'dalinti': 386,
#  'danga': 387,
#  'dangtis': 388,
#  'dangus': 389,
#  'dantis': 390,
#  'dardėti': 391,
#  'dariusirgirėnas': 392,
#  'daroga': 393,
#  'dar': 394,
#  'dartai': 395,
#  'uogienė': 396,
#  'data': 398,
#  'daužyti': 399,
#  'dažai': 400,
#  'dažasvydis': 401,
#  'dažnas': 402,
#  'dažnis': 403,
#  'dažyti': 404,
#  'debesis': 405,
#  'debiutas': 406,
#  'pjūvis': 407,
#  'dėener': 408,
#  'deformuoti': 409,
#  'gabalas': 410,
#  'deglas': 411,
#  'degraduoti': 412,
#  'deimantas': 413,
#  'dėktoi': 414,
#  'dėlė': 415,
#  'delfinas': 416,
#  'delnas': 417,
#  'delyras': 418,
#  'demagogija': 419,
#  'dėmė': 420,
#  'demonas': 421,
#  'dėmuo': 422,
#  'denis': 423,
#  'depozitas': 424,
#  'derėti': 425,
#  'derinti': 426,
#  'dervos': 427,
#  'dešinė': 428,
#  'despasito': 429,
#  'dešra': 430,
#  'detonuoti': 431,
#  'devyni': 432,
#  'dežavu': 433,
#  'diagnozė': 434,
#  'dialogas': 435,
#  'diaunlau': 436,
#  'didelis': 437,
#  'tek': 438,
#  'didžital': 439,
#  'dievas': 440,
#  'baimė': 441,
#  'diktuoti': 442,
#  'gelis': 443,
#  'diktantas': 444,
#  'diletantas': 445,
#  'dilgėlė': 446,
#  'dilti': 447,
#  'dinamitas': 448,
#  'dindilindi': 449,
#  'dingoti': 450,
#  'dirbti': 451,
#  'dirigentas': 452,
#  'dirva': 453,
#  'dirvožemis': 454,
#  'dišovas': 455,
#  'ditirambas': 456,
#  'dizainas': 457,
#  'dobermanas': 458,
#  'dauči': 459,
#  'domino': 460,
#  'dopingas': 461,
#  'doratyeksplora': 462,
#  'doras': 463,
#  'drabužis': 464,
#  'drakula': 465,
#  'dramblys': 466,
#  'drąsus': 467,
#  'draustinis': 468,
#  'drogas': 469,
#  'dručkis': 470,
#  'drugys': 471,
#  'druska': 472,
#  'drybsoti': 473,
#  'dryžius': 474,
#  'dubuo': 475,
#  'dūdmaišis': 476,
#  'dūda': 477,
#  'duetas': 478,
#  'dūkti': 479,
#  'dulkė': 480,
#  'dūmai': 481,
#  'daviklis': 482,
#  'dundėti': 483,
#  'dundulis': 484,
#  'duoklė': 485,
#  'dūra': 486,
#  'durti': 487,
#  'durys': 488,
#  'dušas': 489,
#  'duslus': 490,
#  'dūsti': 491,
#  'dužti': 492,
#  'dvaras': 493,
#  'dvasia': 494,
#  'dvokti': 495,
#  'dvylika': 496,
#  'piršas': 497,
#  'dvylikapirštė': 498,
#  'dykuma': 499,
#  'dylas': 500,
#  'dyvas': 501,
#  'džemas': 502,
#  'džiaugsmas': 503,
#  'džiazas': 504,
#  'dziegorius': 505,
#  'džimisneutronas': 506,
#  'džiumandži': 507,
#  'džonybravo': 508,
#  'džonysins': 509,
#  'dzūkija': 510,
#  'efektas': 511,
#  'ego': 512,
#  'egzorcizmas': 513,
#  'ei': 514,
#  'eigulys': 515,
#  'eismas': 516,
#  'eketė': 517,
#  'ekipažas': 518,
#  'eksterjeras': 519,
#  'elanką': 520,
#  'elasbandis': 521,
#  'elasdė': 522,
#  'elastika': 523,
#  'elektra': 524,
#  'elgeta': 525,
#  'eliksyras': 526,
#  'elipsė': 527,
#  'elitas': 528,
#  'elnias': 529,
#  'emocija': 530,
#  'emsypydžeipurvinis': 531,
#  'energija': 532,
#  'entuziazmas': 533,
#  'enzė': 534,
#  'epušė': 535,
#  'erekcija': 536,
#  'erikabadu': 537,
#  'erkė': 538,
#  'erškėtis': 539,
#  'erškėtrožė': 540,
#  'ešerys': 541,
#  'toks': 542,
#  'etapas': 543,
#  'etika': 544,
#  'etiketė': 545,
#  'eucerinas': 546,
#  'eukaliptas': 547,
#  'euriboras': 548,
#  'eurotripas': 549,
#  'europa': 550,
#  'tripas': 551,
#  'ežeras': 552,
#  'ėžia': 553,
#  'fainas': 554,
#  'faktas': 555,
#  'faladoras': 556,
#  'falsetas': 557,
#  'fanas': 558,
#  'fanta': 559,
#  'fantastika': 560,
#  'fantomas': 561,
#  'faras': 562,
#  'faršas': 563,
#  'fašena': 564,
#  'fazanas': 565,
#  'fererorošė': 566,
#  'festivalis': 567,
#  'figaro': 568,
#  'figa': 569,
#  'figūra': 570,
#  'fikcija': 571,
#  'filologija': 572,
#  'finalas': 573,
#  'fintas': 574,
#  'firma': 575,
#  'fitimiti': 576,
#  'flakonas': 577,
#  'flamingas': 578,
#  'flau': 579,
#  'fleksinti': 580,
#  'flešbengas': 581,
#  'flirtas': 582,
#  'diskas': 583,
#  'flotilė': 584,
#  'fokuspokus': 585,
#  'fondiu': 586,
#  'fondas': 587,
#  'fordas': 588,
#  'formaldehidas': 589,
#  'fortūna': 590,
#  'fry': 591,
#  'fu': 592,
#  'gadinti': 593,
#  'gaidys': 594,
#  'gaivalas': 595,
#  'gaivinti': 596,
#  'galaktika': 597,
#  'galva': 598,
#  'trinkti': 599,
#  'galvijas': 600,
#  'galvoti': 601,
#  'galynėtis': 602,
#  'gama': 603,
#  'gandis': 604,
#  'gandras': 605,
#  'gandas': 606,
#  'gandžia': 607,
#  'garas': 608,
#  'garažas': 609,
#  'garbana': 610,
#  'gardus': 611,
#  'garmėti': 612,
#  'garuoti': 613,
#  'gaublys': 614,
#  'gauti': 615,
#  'gediminoprospektas': 616,
#  'prospektas': 617,
#  'gėda': 618,
#  'gegutė': 619,
#  'gegužė': 620,
#  'gėjus': 621,
#  'gelda': 622,
#  'geležinkelis': 623,
#  'geležis': 624,
#  'gėlas': 625,
#  'geltona': 626,
#  'gemalas': 627,
#  'geras': 628,
#  'gėsinti': 629,
#  'gestapas': 630,
#  'gestas': 631,
#  'gezas': 632,
#  'giedras': 633,
#  'giedoti': 634,
#  'gija': 635,
#  'gilus': 636,
#  'giltinė': 637,
#  'gilzė': 638,
#  'giminė': 639,
#  'gimnastas': 640,
#  'ginklas': 641,
#  'ginti': 642,
#  'gerti': 643,
#  'girė': 644,
#  'girgždėti': 645,
#  'giria': 646,
#  'girnos': 647,
#  'girtas': 648,
#  'gitara': 649,
#  'glaudus': 650,
#  'glėbys': 651,
#  'glaudyti': 652,
#  'gliaudyti': 653,
#  'glitus': 654,
#  'gliūhas': 655,
#  'glodus': 656,
#  'glokas': 657,
#  'glostyti': 658,
#  'glušas': 659,
#  'gobšus': 660,
#  'god': 661,
#  'godus': 662,
#  'golemas': 663,
#  'gongas': 664,
#  'grafas': 665,
#  'grafinas': 666,
#  'grafitas': 667,
#  'grafiti': 668,
#  'granata': 669,
#  'grašis': 670,
#  'graudus': 671,
#  'graviruoti': 672,
#  'greitas': 673,
#  'grėsti': 674,
#  'griauti': 675,
#  'griausmas': 676,
#  'graužti': 677,
#  'griežti': 678,
#  'grindys': 679,
#  'griovys': 680,
#  'griozdas': 681,
#  'grotos': 682,
#  'grožis': 683,
#  'grūdas': 684,
#  'gruodis': 685,
#  'grūšia': 686,
#  'grūtas': 687,
#  'gruzdėti': 688,
#  'gruzija': 689,
#  'grybas': 690,
#  'gryčia': 691,
#  'grynas': 692,
#  'guašas': 693,
#  'gudrus': 694,
#  'gūdus': 695,
#  'gugugaga': 696,
#  'gulbė': 697,
#  'gumbas': 698,
#  'guma': 699,
#  'guolis': 700,
#  'gurgti': 701,
#  'gūsis': 702,
#  'guzas': 703,
#  'gūžta': 704,
#  'gvakamolė': 705,
#  'gynyba': 706,
#  'gyvatė': 707,
#  'hadūken': 708,
#  'hajus': 709,
#  'haking': 710,
#  'hamakas': 711,
#  'harispoteris': 712,
#  'hečbekas': 713,
#  'ernestashemingvėjus': 714,
#  'hemoglobinas': 715,
#  'hemorojus': 716,
#  'hepatitas': 717,
#  'hercogas': 718,
#  'hermafrodiziakas': 719,
#  'heroinas': 720,
#  'hidrochloras': 721,
#  'hidro': 722,
#  'chloras': 723,
#  'hihihaha': 724,
#  'hiperbolė': 725,
#  'hiper': 726,
#  'erdvė': 727,
#  'hipokritas': 728,
#  'hipotezė': 729,
#  'honda': 730,
#  'huanpablito': 731,
#  'harishudinis': 732,
#  'krienas': 733,
#  'berti': 734,
#  'įdaras': 735,
#  'idėja': 736,
#  'idepotentus': 737,
#  'idilė': 738,
#  'įdirbtas': 739,
#  'ieškoti': 740,
#  'ietis': 741,
#  'ieva': 742,
#  'gelti': 743,
#  'griūti': 744,
#  'iguana': 745,
#  'įgula': 746,
#  'gulti': 747,
#  'kašis': 748,
#  'kaušti': 749,
#  'iklotas': 750,
#  'ikras': 751,
#  'ilgas': 752,
#  'ilgėtis': 753,
#  'iliuzija': 754,
#  'iltinis': 755,
#  'imanueliskantas': 756,
#  'impala': 757,
#  'impotentas': 758,
#  'improvizacija': 759,
#  'įnagis': 760,
#  'individas': 761,
#  'indas': 762,
#  'infarktas': 763,
#  'niršti': 764,
#  'įnirtingas': 765,
#  'inkilas': 766,
#  'inkliuzas': 767,
#  'inkstas': 768,
#  'inkšti': 769,
#  'interpretuoti': 770,
#  'introvertas': 771,
#  'invalidas': 772,
#  'įranga': 773,
#  'irklas': 774,
#  'būtybė': 775,
#  'didus': 776,
#  'išeiginė': 777,
#  'esmė': 778,
#  'ganyti': 779,
#  'remti': 780,
#  'įsižeminti': 781,
#  'kabinetas': 782,
#  'fanaras': 783,
#  'kalba': 784,
#  'iškilmė': 785,
#  'šliaužti': 786,
#  'mokyti': 787,
#  'išmonė': 788,
#  'išprusti': 789,
#  'įspūdis': 790,
#  'išradimas': 791,
#  'išsėtinėsklerozė': 792,
#  'gąsdinti': 793,
#  'lavinti': 794,
#  'skėsti': 795,
#  'ištaiga': 796,
#  'ištarti': 797,
#  'istorija': 798,
#  'viduriuoti': 799,
#  'išvirkščias': 800,
#  'išvis': 801,
#  'įtaiga': 802,
#  'įtaka': 803,
#  'įtūžis': 804,
#  'įžambinė': 805,
#  'žengti': 806,
#  'įžanga': 807,
#  'izoliacija': 808,
#  'jachta': 809,
#  'jacis': 810,
#  'jankis': 811,
#  'jaunas': 812,
#  'jausmas': 813,
#  'jautis': 814,
#  'jazminas': 815,
#  'jeigu': 816,
#  'joga': 817,
#  'joti': 818,
#  'judinti': 819,
#  'jungti': 820,
#  'juodas': 821,
#  'juokas': 822,
#  'juoktis': 823,
#  'jupiteris': 824,
#  'jūratė': 825,
#  'jurginas': 826,
#  'jūra': 827,
#  'juška': 828,
#  'juvelyras': 829,
#  'baras': 830,
#  'kabina': 831,
#  'kablys': 832,
#  'kabėti': 833,
#  'ėdalas': 834,
#  'dėvėti': 835,
#  'kaimas': 836,
#  'kairė': 837,
#  'kaitinti': 838,
#  'kai': 839,
#  'kakariekų': 840,
#  'kakėmakė': 841,
#  'kaklas': 842,
#  'kaka': 843,
#  'kaladė': 844,
#  'kalafijoras': 845,
#  'kalakutas': 846,
#  'kalbėti': 847,
#  'kalėdos': 848,
#  'kalė': 849,
#  'kalgon': 850,
#  'kaligula': 851,
#  'kalėti': 852,
#  'kaliošas': 853,
#  'kalkė': 854,
#  'gūbrys': 855,
#  'kalorija': 856,
#  'kalvinandklain': 857,
#  'kalvis': 858,
#  'kamanė': 859,
#  'kamanos': 860,
#  'kambarys': 861,
#  'kamera': 862,
#  'kamerondijas': 863,
#  'kamienas': 864,
#  'kampas': 865,
#  'kamuolys': 866,
#  'kanalas': 867,
#  'kanalizacija': 868,
#  'kancaras': 869,
#  'kančia': 870,
#  'kandas': 871,
#  'kanibalas': 872,
#  'kanistras': 873,
#  'kankinti': 874,
#  'kanklės': 875,
#  'kanoja': 876,
#  'kanopa': 877,
#  'kantas': 878,
#  'kapas': 879,
#  'kapišonas': 880,
#  'kapitalas': 881,
#  'kapitonas': 882,
#  'kapa': 883,
#  'kaplys': 884,
#  'kapoti': 885,
#  'kapotas': 886,
#  'kaprizas': 887,
#  'kapstyti': 888,
#  'kaip': 889,
#  'karatė': 890,
#  'karbonadas': 891,
#  'karčiai': 892,
#  'kardio': 893,
#  'kardas': 894,
#  'karibai': 895,
#  'karieta': 896,
#  'karkalas': 897,
#  'karka': 898,
#  'karnišonas': 899,
#  'karpis': 900,
#  'karštis': 901,
#  'karšis': 902,
#  'karštas': 903,
#  'karstas': 904,
#  'kartas': 905,
#  'karūna': 906,
#  'karvė': 907,
#  'karas': 908,
#  'varnėnas': 909,
#  'kašikas': 910,
#  'kada': 911,
#  'kasekas': 912,
#  'kasparas': 913,
#  'kaspinas': 914,
#  'kastetas': 915,
#  'kastuvas': 916,
#  'kąstytis': 917,
#  'katalizatorius': 918,
#  'katalogas': 919,
#  'katarsis': 920,
#  'kad': 921,
#  'katilas': 922,
#  'vitalijakatunskytė': 923,
#  'katutės': 924,
#  'kauabanga': 925,
#  'kaukė': 926,
#  'kaulelis': 927,
#  'kaunas': 928,
#  'kaušas': 929,
#  'kautis': 930,
#  'kava': 931,
#  'aparatas': 932,
#  'kazanova': 933,
#  'kazlėkas': 934,
#  'kebabas': 935,
#  'keberiokšt': 936,
#  'kečiupas': 937,
#  'kėdė': 938,
#  'kedenti': 939,
#  'kefyras': 940,
#  'keiktis': 941,
#  'styvenaskeisis': 942,
#  'keistas': 943,
#  'kekė': 944,
#  'kekšė': 945,
#  'keliauti': 946,
#  'kėlinys': 947,
#  'kelias': 948,
#  'kelis': 949,
#  'keli': 950,
#  'kelmas': 951,
#  'kelnės': 952,
#  'keltas': 953,
#  'kenas': 954,
#  'kenkėjas': 955,
#  'kepalas': 956,
#  'kepasa': 957,
#  'kepenys': 958,
#  'kepsninė': 959,
#  'kepsnys': 960,
#  'duona': 961,
#  'kepti': 962,
#  'kepurė': 963,
#  'kerai': 964,
#  'kerėpla': 965,
#  'vytautaskernagis': 966,
#  'kesimpta': 967,
#  'kesti': 968,
#  'ketaminas': 969,
#  'keto': 970,
#  'penkiasdešimt': 971,
#  'keturi': 972,
#  'dobilas': 973,
#  'keturlapisdobilas': 974,
#  'kiaunė': 975,
#  'kiauras': 976,
#  'kibinas': 977,
#  'kiekis': 978,
#  'kiek': 979,
#  'kielė': 980,
#  'kietys': 981,
#  'kilimanžaras': 982,
#  'kilimas': 983,
#  'kilo': 984,
#  'vatas': 985,
#  'kiminas': 986,
#  'kinas': 987,
#  'kingkong': 988,
#  'kinkyti': 989,
#  'kirtis': 990,
#  'kirkšnis': 991,
#  'kirmėlė': 992,
#  'kiras': 993,
#  'kirpti': 994,
#  'kirsti': 995,
#  'kirvis': 996,
#  'kišenė': 997,
#  'keisti': 998,
#  'kitaip': 999,
#  'klaida': 1000,
#  'klaikus': 1001,
#  ...}

# %%
core_thing = tuple((core_to_core_id[core], core_to_core_id[core]) for core in core_to_core_id)

# %%
cur.execute(f"SELECT morph_id, id FROM cores")
core_core = cur.fetchall()

# %%
cur.executemany(f'INSERT INTO morphs_cores (morph_id, core_id) VALUES (%s, %s) ON CONFLICT DO NOTHING', core_core)
conn.commit()

# %%
cur.execute("SELECT morph FROM MORPHS WHERE id NOT in (SELECT morph_id FROM morphs_cores)")
cur.fetchall()
# Out:
# [('mažolavašosupikantiškupaprašo',),
#  ('bizynes',),
#  ('dadu',),
#  ('q\t',),
#  ('bingobangobongobišbašboš',),
#  ('nekilmingo',),
#  ('cėpėtėesdė',),
#  ('čikuraku',),
#  ('plaukt',),
#  ('auplyz',),
#  ('čingadomadreputas',),
#  ('pavyzdžiai',),
#  ('tekriukteli',),
#  ('čekinas',)]

# %%
cur.fetchall()
# Out:
# [('bulviųsalotos',), ('daržovė',)]

# %%
cur.execute(f"SELECT morph FROM morphs WHERE morph in %s", (("daržovė", "bulviųsalotos"),))

# %%
patterns = read_chunks("blokai")

# %%
patterns = tuple((s[0].partition("~")[0]).lower() for s in patterns[1:])

# %%
patterns = patterns[:-1]

# %%
patterns = tuple((item,) for item in patterns)

# %%
patterns
# Out:
# (('yb',),
#  ('[šž][tvmknlpg]?[iė][sš]$',),
#  ('š(e|ę|ia)s$',),
#  ('or',),
#  ('oga$',),
#  ('ogas$',),
#  ('ogis$',),
#  ('og',),
#  ('p[aęe]s',),
#  ('š[ae]is',),
#  ('utės',),
#  ('uos$',),
#  ('uos',),
#  ('als(u|o|io)',),
#  ('us$',),
#  ('(č|dž)iau',),
#  ('als',),
#  ('(k|m)?als',),
#  ('uot',),
#  ('ož',),
#  ('či(ų|u)',),
#  ('iek',),
#  ('t[o|e]li$',),
#  ('il(n|m)(ų|o)$',),
#  ('dži[uų]$',),
#  ('ik[r|l][aąe]$',),
#  ('ėd',),
#  ('ėd[^(av)]',),
#  ('atu',),
#  ('eik(ia|e)',),
#  ('ynas',),
#  ('yn',),
#  ('vų',),
#  ('ysiu$',),
#  ('rog',),
#  ('van',),
#  ('l[eėi]tas$',),
#  ('d[eė]tas$',),
#  ('m[eė]tas$',),
#  ('g[eė]l',),
#  ('atl',),
#  ('tle',),
#  ('l(ie|ė)tas$',),
#  ('l(ie)tas$',),
#  ('l(e|ė)tas$',),
#  ('gyv',),
#  ('vat[ėe]$',),
#  ('rat[ėe]$',),
#  ('at[ėe]$',),
#  ('yv',),
#  ('g[yi][vrkl]',),
#  ('ara$',),
#  ('era',),
#  ('era$',),
#  ('ven',),
#  ('pir',),
#  ('^pir',),
#  ('kir',),
#  ('bur',),
#  ('kur',),
#  ('uog',),
#  ('uo[mn]is',),
#  ('uolis$',),
#  ('akt(as|is)',),
#  ('akt(as|is|a)',),
#  ('eit',),
#  ('rai$',),
#  ('oja$',),
#  ('ažas',),
#  ('aža',),
#  ('(?<!i)(ia|e)žas',),
#  ('ežti',),
#  ('ežti$',),
#  ('ežęs$',),
#  ('ūkas',),
#  ('yč(ia|e)',),
#  ('yr[ia](ai|s)',),
#  ('ir(e|ia)',),
#  ('iak',),
#  ('akas',),
#  ('(v|k)oti$',),
#  ('(v|k)ojai$',),
#  ('riuota',),
#  ('ojis',),
#  ('ojus',),
#  ('oj(u|i)s',),
#  ('ur(io|e|ia|ė)s?',),
#  ('[^ž]olė',),
#  ('nata',),
#  ('ata$',),
#  ('ovas',),
#  ('ta$',),
#  ('esti',),
#  ('oz(ia|e|ė)',),
#  ('ai(ž|š)',),
#  ('eiz',),
#  ('ūka',),
#  ('ovė',),
#  ('yra',),
#  ('ožti',),
#  ('ož[ėei]([mn][iėe])?s',),
#  ('anas?$',),
#  ('upin',),
#  ('š((čiai)|(tis)|(ei)|(yti))',),
#  ('š.{1}(ies|ės)',),
#  ('[žš].ė$',),
#  ('[^s](ū|u)vis',),
#  ('š(e|ę|ia)s$',),
#  ('š.is$',),
#  ('str',),
#  ('or(i)?(as|o)$',),
#  ('il(n|m)(ų|o)$',),
#  ('inas$',))

# %%
cur.executemany(f"INSERT INTO patterns (pattern) VALUES (%s)", patterns)

# %%
conn.commit()

# %%
conn.rollback()

# %%
select_morph_id_core_id_query = f"""
SELECT m.id, c.morph_id
FROM morphs m
LEFT JOIN morphs_clusters mc
ON m.id = mc.morph_id
LEFT JOIN cores c
ON mc.cluster_id = c.id
WHERE m.morph in %s
"""

# %%
cur.execute(select_morph_id_core_id_query, (("daržovė",),))
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 cur.execute(select_morph_id_core_id_query, (("daržovė",),))
#
# UndefinedColumn: column c.morph_id does not exist
# LINE 2: SELECT m.id, c.morph_id
#                      ^
# HINT:  Perhaps you meant to reference the column "mc.morph_id".

# %%
cur.execute(f"select morph_id from cores")
cur.fetchall()
# Out:
# [(24036,),
#  (7544,),
#  (4511,),
#  (9425,),
#  (12609,),
#  (8500,),
#  (977,),
#  (7538,),
#  (1001,),
#  (1140,),
#  (1303,),
#  (1486,),
#  (7707,),
#  (1547,),
#  (1561,),
#  (8530,),
#  (8529,),
#  (1648,),
#  (8997,),
#  (8556,),
#  (1925,),
#  (1635,),
#  (1729,),
#  (1894,),
#  (1904,),
#  (2053,),
#  (7914,),
#  (2212,),
#  (2609,),
#  (7931,),
#  (2620,),
#  (2499,),
#  (2636,),
#  (5546,),
#  (8005,),
#  (2289,),
#  (1545,),
#  (8046,),
#  (5591,),
#  (5617,),
#  (5781,),
#  (4166,),
#  (2158,),
#  (4890,),
#  (8187,),
#  (8111,),
#  (9047,),
#  (8624,),
#  (8105,),
#  (6018,),
#  (4502,),
#  (783,),
#  (6873,),
#  (2248,),
#  (6945,),
#  (1519,),
#  (1282,),
#  (1567,),
#  (8448,),
#  (9255,),
#  (9954,),
#  (9786,),
#  (10159,),
#  (9028,),
#  (10563,),
#  (10647,),
#  (1825,),
#  (10603,),
#  (10577,),
#  (3089,),
#  (10700,),
#  (10596,),
#  (10565,),
#  (10619,),
#  (10694,),
#  (10545,),
#  (10583,),
#  (10690,),
#  (10582,),
#  (10622,),
#  (10651,),
#  (8068,),
#  (10689,),
#  (10634,),
#  (10566,),
#  (9065,),
#  (4169,),
#  (8143,),
#  (12789,),
#  (12790,),
#  (12791,),
#  (12801,),
#  (8463,),
#  (12806,),
#  (12811,),
#  (12817,),
#  (1364,),
#  (12691,),
#  (12698,),
#  (10268,),
#  (12700,),
#  (12701,),
#  (10041,),
#  (12709,),
#  (8613,),
#  (8356,),
#  (12714,),
#  (12716,),
#  (10327,),
#  (12718,),
#  (9245,),
#  (1463,),
#  (1120,),
#  (12732,),
#  (12734,),
#  (8918,),
#  (10038,),
#  (10227,),
#  (1628,),
#  (1485,),
#  (6436,),
#  (12754,),
#  (12755,),
#  (12756,),
#  (12757,),
#  (12760,),
#  (12761,),
#  (6226,),
#  (12771,),
#  (10542,),
#  (12773,),
#  (12775,),
#  (12776,),
#  (12821,),
#  (12823,),
#  (12814,),
#  (12828,),
#  (12834,),
#  (5404,),
#  (6475,),
#  (5767,),
#  (12855,),
#  (10172,),
#  (8280,),
#  (10274,),
#  (12867,),
#  (12870,),
#  (751,),
#  (1283,),
#  (12884,),
#  (12887,),
#  (5794,),
#  (2193,),
#  (1141,),
#  (1846,),
#  (12897,),
#  (12895,),
#  (12900,),
#  (8333,),
#  (12904,),
#  (3082,),
#  (9457,),
#  (7689,),
#  (8601,),
#  (12914,),
#  (12921,),
#  (12922,),
#  (12927,),
#  (12928,),
#  (12930,),
#  (12934,),
#  (12935,),
#  (12937,),
#  (7998,),
#  (12940,),
#  (3982,),
#  (12943,),
#  (12944,),
#  (12946,),
#  (5397,),
#  (5398,),
#  (7624,),
#  (8705,),
#  (12953,),
#  (12961,),
#  (9547,),
#  (12964,),
#  (5432,),
#  (12968,),
#  (5048,),
#  (7742,),
#  (12970,),
#  (12750,),
#  (12751,),
#  (12684,),
#  (1300,),
#  (12986,),
#  (12991,),
#  (12992,),
#  (12996,),
#  (6412,),
#  (5076,),
#  (3097,),
#  (13001,),
#  (8087,),
#  (13005,),
#  (722,),
#  (9784,),
#  (9292,),
#  (6415,),
#  (13010,),
#  (1816,),
#  (1145,),
#  (3979,),
#  (10180,),
#  (9419,),
#  (13021,),
#  (2318,),
#  (13027,),
#  (6054,),
#  (4513,),
#  (5912,),
#  (13036,),
#  (13039,),
#  (13040,),
#  (13042,),
#  (9186,),
#  (13046,),
#  (4172,),
#  (13050,),
#  (5778,),
#  (13053,),
#  (5082,),
#  (1435,),
#  (1621,),
#  (6166,),
#  (10242,),
#  (13064,),
#  (13065,),
#  (2366,),
#  (2207,),
#  (804,),
#  (1630,),
#  (4250,),
#  (13077,),
#  (8017,),
#  (824,),
#  (8692,),
#  (2268,),
#  (8573,),
#  (13087,),
#  (5747,),
#  (13090,),
#  (13094,),
#  (8014,),
#  (8015,),
#  (1830,),
#  (13102,),
#  (13106,),
#  (2754,),
#  (1230,),
#  (13112,),
#  (5672,),
#  (6210,),
#  (9071,),
#  (13121,),
#  (13122,),
#  (9841,),
#  (13125,),
#  (13126,),
#  (4984,),
#  (13129,),
#  (9344,),
#  (5303,),
#  (9191,),
#  (1334,),
#  (13137,),
#  (8331,),
#  (13139,),
#  (13147,),
#  (1267,),
#  (12899,),
#  (1935,),
#  (8373,),
#  (13156,),
#  (836,),
#  (1905,),
#  (5370,),
#  (13161,),
#  (13163,),
#  (13164,),
#  (8349,),
#  (7600,),
#  (9865,),
#  (2425,),
#  (8211,),
#  (2113,),
#  (5760,),
#  (1590,),
#  (2979,),
#  (10085,),
#  (3899,),
#  (5797,),
#  (9212,),
#  (7852,),
#  (13205,),
#  (13206,),
#  (9497,),
#  (8702,),
#  (13215,),
#  (808,),
#  (2677,),
#  (9668,),
#  (9669,),
#  (1804,),
#  (13221,),
#  (7704,),
#  (13224,),
#  (13225,),
#  (9725,),
#  (13227,),
#  (1256,),
#  (13238,),
#  (1376,),
#  (8249,),
#  (8517,),
#  (1304,),
#  (13250,),
#  (9846,),
#  (3971,),
#  (13260,),
#  (6818,),
#  (13267,),
#  (3923,),
#  (13183,),
#  (4175,),
#  (13277,),
#  (1045,),
#  (1329,),
#  (13283,),
#  (10503,),
#  (5979,),
#  (2025,),
#  (9662,),
#  (6768,),
#  (13291,),
#  (2222,),
#  (3977,),
#  (4499,),
#  (13296,),
#  (7948,),
#  (7946,),
#  (10537,),
#  (13302,),
#  (13303,),
#  (13304,),
#  (7949,),
#  (4769,),
#  (13310,),
#  (5980,),
#  (7009,),
#  (10476,),
#  (13316,),
#  (7748,),
#  (7699,),
#  (3673,),
#  (1352,),
#  (9184,),
#  (13322,),
#  (13323,),
#  (13326,),
#  (2436,),
#  (4506,),
#  (6399,),
#  (5506,),
#  (5748,),
#  (13338,),
#  (13340,),
#  (7698,),
#  (2148,),
#  (9277,),
#  (9196,),
#  (8565,),
#  (10423,),
#  (13356,),
#  (1981,),
#  (13358,),
#  (1206,),
#  (7561,),
#  (9210,),
#  (8006,),
#  (13376,),
#  (3942,),
#  (13380,),
#  (13378,),
#  (13386,),
#  (13387,),
#  (7544,),
#  (10160,),
#  (5829,),
#  (2308,),
#  (8577,),
#  (1129,),
#  (1461,),
#  (7221,),
#  (7759,),
#  (5697,),
#  (1232,),
#  (5722,),
#  (13422,),
#  (13423,),
#  (1078,),
#  (13425,),
#  (7642,),
#  (13435,),
#  (6507,),
#  (4180,),
#  (9297,),
#  (10191,),
#  (13440,),
#  (13441,),
#  (8440,),
#  (5413,),
#  (10088,),
#  (10523,),
#  (9873,),
#  (13449,),
#  (9923,),
#  (2793,),
#  (13456,),
#  (9417,),
#  (13462,),
#  (6528,),
#  (1600,),
#  (13468,),
#  (1626,),
#  (9760,),
#  (2578,),
#  (13477,),
#  (13478,),
#  (13479,),
#  (12994,),
#  (13481,),
#  (13482,),
#  (8069,),
#  (4459,),
#  (13485,),
#  (9628,),
#  (993,),
#  (8523,),
#  (13490,),
#  (2724,),
#  (1903,),
#  (13497,),
#  (7540,),
#  (13506,),
#  (1151,),
#  (4252,),
#  (1445,),
#  (2377,),
#  (6257,),
#  (13516,),
#  (4466,),
#  (4465,),
#  (13522,),
#  (10156,),
#  (1756,),
#  (13525,),
#  (1055,),
#  (2258,),
#  (1914,),
#  (8119,),
#  (7536,),
#  (13540,),
#  (1110,),
#  (7466,),
#  (1411,),
#  (13544,),
#  (1274,),
#  (13552,),
#  (13553,),
#  (10398,),
#  (10475,),
#  (10517,),
#  (1944,),
#  (8438,),
#  (1928,),
#  (13576,),
#  (9274,),
#  (4777,),
#  (13582,),
#  (9860,),
#  (13585,),
#  (13586,),
#  (13587,),
#  (13592,),
#  (13593,),
#  (13594,),
#  (8269,),
#  (8652,),
#  (1858,),
#  (1896,),
#  (2036,),
#  (13602,),
#  (8332,),
#  (5295,),
#  (7754,),
#  (10462,),
#  (9498,),
#  (1476,),
#  (1205,),
#  (8653,),
#  (3973,),
#  (10387,),
#  (2017,),
#  (8571,),
#  (8687,),
#  (5491,),
#  (2006,),
#  (5913,),
#  (6458,),
#  (854,),
#  (2797,),
#  (1950,),
#  (9622,),
#  (8605,),
#  (9279,),
#  (909,),
#  (13654,),
#  (9673,),
#  (13656,),
#  (1920,),
#  (13658,),
#  (13662,),
#  (13663,),
#  (13665,),
#  (2224,),
#  (2971,),
#  (3315,),
#  (13671,),
#  (13676,),
#  (8930,),
#  (13684,),
#  (2405,),
#  (8259,),
#  (13688,),
#  (5482,),
#  (13691,),
#  (3968,),
#  (8714,),
#  (13693,),
#  (13696,),
#  (8927,),
#  (1201,),
#  (4497,),
#  (2281,),
#  (7709,),
#  (9606,),
#  (13704,),
#  (8070,),
#  (1361,),
#  (9781,),
#  (2398,),
#  (13709,),
#  (13710,),
#  (1589,),
#  (5921,),
#  (8473,),
#  (1873,),
#  (13715,),
#  (7800,),
#  (8925,),
#  (13720,),
#  (5335,),
#  (3088,),
#  (13724,),
#  (3079,),
#  (1434,),
#  (13728,),
#  (1862,),
#  (13730,),
#  (3099,),
#  (2427,),
#  (1147,),
#  (1000,),
#  (6008,),
#  (1052,),
#  (9326,),
#  (13743,),
#  (2153,),
#  (1353,),
#  (7411,),
#  (1263,),
#  (13751,),
#  (1962,),
#  (13756,),
#  (13757,),
#  (793,),
#  (8674,),
#  (13783,),
#  (7821,),
#  (2536,),
#  (9769,),
#  (1839,),
#  (7845,),
#  (3984,),
#  (1117,),
#  (5753,),
#  (1852,),
#  (1062,),
#  (13799,),
#  (13802,),
#  (9094,),
#  (9025,),
#  (744,),
#  (13370,),
#  (13816,),
#  (13817,),
#  (1039,),
#  (7865,),
#  (2737,),
#  (2311,),
#  (13826,),
#  (8691,),
#  (8026,),
#  (5683,),
#  (13840,),
#  (1595,),
#  (2481,),
#  (13854,),
#  (2059,),
#  (13858,),
#  (6211,),
#  (9209,),
#  (13860,),
#  (1313,),
#  (13865,),
#  (13866,),
#  (13867,),
#  (13868,),
#  (2147,),
#  (10452,),
#  (9492,),
#  (13847,),
#  (13873,),
#  (8091,),
#  (2440,),
#  (1832,),
#  (13880,),
#  (6231,),
#  (13882,),
#  (5680,),
#  (13884,),
#  (10083,),
#  (13886,),
#  (4901,),
#  (13888,),
#  (4968,),
#  (9309,),
#  (4779,),
#  (13896,),
#  (13897,),
#  (7734,),
#  (845,),
#  (787,),
#  (6446,),
#  (4184,),
#  (9063,),
#  (3078,),
#  (1421,),
#  (2432,),
#  (13917,),
#  (9940,),
#  (13924,),
#  (13927,),
#  (13929,),
#  (13930,),
#  (13918,),
#  (8263,),
#  (1841,),
#  (8120,),
#  (13937,),
#  (1869,),
#  (13921,),
#  (13946,),
#  (2586,),
#  (13949,),
#  (1537,),
#  (8537,),
#  (13955,),
#  (8041,),
#  (1042,),
#  (2434,),
#  (9351,),
#  (13966,),
#  (13967,),
#  (1105,),
#  (8330,),
#  (6410,),
#  (13972,),
#  (3032,),
#  (13975,),
#  (7580,),
#  (13978,),
#  (2201,),
#  (856,),
#  (10451,),
#  (1722,),
#  (7513,),
#  (8172,),
#  (5618,),
#  (2236,),
#  (3896,),
#  (1874,),
#  (14004,),
#  (2543,),
#  (6519,),
#  (1637,),
#  (2324,),
#  (1772,),
#  (4256,),
#  (14015,),
#  (14016,),
#  (13305,),
#  (8136,),
#  (2676,),
#  (14023,),
#  (2110,),
#  (4457,),
#  (14026,),
#  (5393,),
#  (2137,),
#  (14029,),
#  (14032,),
#  (13103,),
#  (14035,),
#  (2024,),
#  (14038,),
#  (1582,),
#  (14040,),
#  (9830,),
#  (2413,),
#  (3989,),
#  (2429,),
#  (14049,),
#  (1509,),
#  (759,),
#  (14052,),
#  (2115,),
#  (12820,),
#  (10463,),
#  (1568,),
#  (2628,),
#  (14060,),
#  (14061,),
#  (14062,),
#  (2122,),
#  (14065,),
#  (2390,),
#  (1583,),
#  (1609,),
#  (14072,),
#  (14073,),
#  (1919,),
#  (14076,),
#  (14077,),
#  (1315,),
#  (9847,),
#  (14085,),
#  (8075,),
#  (14089,),
#  (6978,),
#  (14091,),
#  (9337,),
#  (9537,),
#  (14100,),
#  (13472,),
#  (8600,),
#  (13683,),
#  (12971,),
#  (14113,),
#  (14115,),
#  (14116,),
#  (983,),
#  (14119,),
#  (14122,),
#  (14123,),
#  (14129,),
#  (14126,),
#  (14135,),
#  (14136,),
#  (14138,),
#  (1137,),
#  (13805,),
#  (14144,),
#  (14151,),
#  (14152,),
#  (14153,),
#  (7691,),
#  (14161,),
#  (883,),
#  (2996,),
#  (14167,),
#  (14168,),
#  (4762,),
#  (8980,),
#  (14172,),
#  (8977,),
#  (1155,),
#  (1640,),
#  (8129,),
#  (10223,),
#  (2709,),
#  (14182,),
#  (7820,),
#  (4186,),
#  (2816,),
#  (1251,),
#  (8678,),
#  (14196,),
#  (14198,),
#  (10200,),
#  (8393,),
#  (8392,),
#  (10153,),
#  (1066,),
#  (4188,),
#  (1711,),
#  (10210,),
#  (7978,),
#  (13035,),
#  (4491,),
#  (8419,),
#  (9476,),
#  (14238,),
#  (5049,),
#  (14249,),
#  (2448,),
#  (14255,),
#  (7356,),
#  (6810,),
#  (14262,),
#  (1122,),
#  (14258,),
#  (3096,),
#  (12690,),
#  (8001,),
#  (2545,),
#  (2410,),
#  (3921,),
#  (5595,),
#  (2349,),
#  (5446,),
#  (14291,),
#  (14293,),
#  (14296,),
#  (14298,),
#  (8484,),
#  (9263,),
#  (9226,),
#  (975,),
#  (6860,),
#  (8261,),
#  (939,),
#  (7677,),
#  (5793,),
#  (5390,),
#  (14319,),
#  (1394,),
#  (10099,),
#  (9074,),
#  (2217,),
#  (5334,),
#  (1093,),
#  (14332,),
#  (8363,),
#  (8668,),
#  (1474,),
#  (1332,),
#  (823,),
#  (1777,),
#  (5337,),
#  (8335,),
#  (1108,),
#  (6400,),
#  (8404,),
#  (6212,),
#  (14358,),
#  (14359,),
#  (2423,),
#  (1349,),
#  (3071,),
#  (1032,),
#  (14372,),
#  (743,),
#  (1127,),
#  (2339,),
#  (8297,),
#  (730,),
#  (1477,),
#  (8932,),
#  (14388,),
#  (1130,),
#  (8917,),
#  (14390,),
#  (2106,),
#  (10399,),
#  (7819,),
#  (10279,),
#  (6406,),
#  (1673,),
#  (838,),
#  (795,),
#  (1398,),
#  (4191,),
#  (10511,),
#  (7898,),
#  (2109,),
#  (4461,),
#  (1024,),
#  (7669,),
#  (14428,),
#  (961,),
#  (14435,),
#  (2101,),
#  (1183,),
#  (14439,),
#  (14443,),
#  (941,),
#  (4781,),
#  (9504,),
#  (7633,),
#  (7637,),
#  (1916,),
#  (6361,),
#  (1574,),
#  (8407,),
#  (14458,),
#  (1958,),
#  (14461,),
#  (9338,),
#  (14463,),
#  (1264,),
#  (8309,),
#  (8007,),
#  (14477,),
#  (966,),
#  (1311,),
#  (7783,),
#  (2072,),
#  (2732,),
#  (8481,),
#  (8107,),
#  (14500,),
#  (6055,),
#  (2161,),
#  (1562,),
#  (2368,),
#  (2808,),
#  (9728,),
#  (9727,),
#  (8113,),
#  (8989,),
#  (5735,),
#  (8509,),
#  (8402,),
#  (14524,),
#  (1331,),
#  (8246,),
#  (2291,),
#  (1185,),
#  (14533,),
#  (6523,),
#  (8165,),
#  (8167,),
#  (8544,),
#  (10212,),
#  (5662,),
#  (1690,),
#  (14550,),
#  (14554,),
#  (9080,),
#  (2325,),
#  (1071,),
#  (14565,),
#  (14566,),
#  (4193,),
#  (894,),
#  (4448,),
#  (14572,),
#  (14574,),
#  (5634,),
#  (8531,),
#  (7317,),
#  (14579,),
#  (14581,),
#  (7899,),
#  (14589,),
#  (7871,),
#  (1867,),
#  ...]

# %%
conn.rollback()
